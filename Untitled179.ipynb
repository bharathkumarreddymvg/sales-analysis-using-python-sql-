# %% [markdown]
# # sales analysis using python and sql

# %% [markdown]
# ### import the pandas library and read the file

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\bhara\Downloads\orders.csv\orders.csv")
df.head()
# Out:
#    Order Id  Order Date       Ship Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %% [markdown]
# ### check the null values

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', nan, 'Same Day'], dtype=object)

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Order Id  Order Date Ship Mode    Segment        Country     City  \
# 118       119  2023-07-19       NaN  Corporate  United States  Bristol
#
#          State  Postal Code Region         Category Sub Category  \
# 118  Tennessee        37620  South  Office Supplies      Binders
#
#           Product Id  cost price  List Price  Quantity  Discount Percent
# 118  OFF-BI-10003650         140         160         1                 5

# %% [markdown]
# ### fill the null values

# %%
df['Ship Mode'].fillna('Not Available',inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Order Id, Order Date, Ship Mode, Segment, Country, City, State, Postal Code, Region, Category, Sub Category, Product Id, cost price, List Price, Quantity, Discount Percent]
# Index: []

# %% [markdown]
# ### modify the column names for data analysis

# %%
df.columns=df.columns.str.lower()

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
df['discounts']=df['list_price']*df['discount_percent']*.01
df['sales_price']=df['list_price']-df['discounts']
df['profit']=df['sales_price']-df['cost_price']
df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %% [markdown]
# ### check the data types of each columns

# %%
df.dtypes
# Out:
# order_id              int64
# order_date           object
# ship_mode            object
# segment              object
# country              object
# city                 object
# state                object
# postal_code           int64
# region               object
# category             object
# sub_category         object
# product_id           object
# cost_price            int64
# list_price            int64
# quantity              int64
# discount_percent      int64
# discounts           float64
# sales_price         float64
# profit              float64
# dtype: object

# %% [markdown]
# ### delete the unneccasary columns in the table

# %%
df1=df.drop(columns=['list_price','cost_price','discount_percent'],inplace=True)

# %% [markdown]
# ### modify the data types in the columns

# %%
df1 = df.copy()
df1['order_date'] = pd.to_datetime(df1['order_date'], format='%Y-%m-%d')

# %%
df1.dtypes
# Out:
# order_id                 int64
# order_date      datetime64[ns]
# ship_mode               object
# segment                 object
# country                 object
# city                    object
# state                   object
# postal_code              int64
# region                  object
# category                object
# sub_category            object
# product_id              object
# quantity                 int64
# discounts              float64
# sales_price            float64
# profit                 float64
# dtype: object

# %%
### install the mys

# %%
# !pip install mysql-connector-python sqlalchemy

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqlconnector://root:Bharath12345@localhost:3306/store_db")

# %%
conn=engine.connect()
df1.to_sql('df1', con=conn , index=False, if_exists = 'append')
# Out:
# 9994

# %%
df1.head()
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discounts  sales_price  profit
# 0    Bookcases  FUR-BO-10001798         2        5.2        254.8    14.8
# ...
